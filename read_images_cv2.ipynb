# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
import cv2   
import skimage
from skimage.transform import resize 


X=[]
y=[]

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
#         print(os.path.join(dirname, filename))
        filename = os.path.join(dirname, filename) 
        print (filename)
        img = cv2.imread(filename,cv2.IMREAD_GRAYSCALE)
        if img is not None:
                img = skimage.transform.resize(img, (28,28, 1))
                img = np.asarray(img)
                label=filename.split('/')[-2]
                print (img.shape, label)
                X.append(img)
                y.append(label)
                
X = np.asarray(X)
y = np.asarray(y)
        
# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/.DS_Store
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/.DS_Store
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0033-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0050-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0011-0001-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0173-0001-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0232-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0294-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0001-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0079-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0097-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0201-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0277-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0025-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0329-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0049-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0037-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0315-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0372-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0093-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0241-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0237-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0348-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0351-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0333-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0145-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0030-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0276-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0274-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0317-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0131-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0343-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0288-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0229-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0370-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0374-0001-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0075-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0305-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0099-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0195-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0091-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0354-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0273-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0033-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0123-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0249-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0073-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0086-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0041-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0130-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0092-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0079-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0171-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0278-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0135-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0267-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0325-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0350-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0033-0001-0002.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0347-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0120-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0311-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0336-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0207-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0070-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0109-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0059-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0036-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0332-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0361-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0060-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0374-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0033-0001-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0006-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0210-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0102-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0021-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0310-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0238-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0374-0001-0002.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0309-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0233-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0303-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0011-0001-0002.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0322-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0290-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0031-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0199-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0285-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0096-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0052-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0381-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0105-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0023-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0009-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0129-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0095-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0251-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0083-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0369-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0360-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0331-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0010-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0003-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0028-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0304-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0292-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0012-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0027-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0007-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0059-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0373-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0017-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0071-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0013-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0089-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0312-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0259-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0300-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0307-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0072-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0335-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0141-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0087-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0380-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0011-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0073-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0022-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0111-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0019-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0069-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0362-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0103-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0217-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0117-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0353-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0132-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0085-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0039-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0222-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0198-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0067-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0041-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0102-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0271-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0246-0001-0002.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0035-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0357-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0023-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0330-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0366-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0058-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0030-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0150-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0043-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0007-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0339-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0206-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0289-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0105-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0364-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0146-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0063-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0328-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0112-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0139-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0213-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0081-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0015-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0086-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0368-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0345-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0219-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0282-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0352-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0095-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0066-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0098-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0107-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0323-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0019-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0110-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0301-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0319-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0045-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0283-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0005-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0081-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0246-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0326-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0287-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0321-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0111-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0027-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0346-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0077-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0035-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0349-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0051-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0196-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0316-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0029-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0221-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0107-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0280-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0246-0001-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0378-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0337-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0173-0001-0002.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0272-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0029-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0028-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0279-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0061-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0341-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0338-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0286-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0046-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0084-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0376-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0016-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0359-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0013-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0327-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0302-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0065-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0297-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0256-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0340-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0275-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0281-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0101-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0313-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/IM-0045-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0110-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/NORMAL/NORMAL2-IM-0252-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person76_virus_138.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1676_virus_2892.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person96_bacteria_464.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person138_bacteria_657.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person174_bacteria_832.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1613_virus_2799.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person100_bacteria_481.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person108_bacteria_504.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1675_virus_2891.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person25_virus_59.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person78_bacteria_381.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person51_virus_105.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1664_virus_2877.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person43_virus_92.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person138_bacteria_658.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person67_virus_126.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1635_virus_2831.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person16_virus_47.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1_virus_11.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person89_bacteria_440.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1633_virus_2829.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person146_bacteria_703.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person124_bacteria_592.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person83_bacteria_412.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person158_bacteria_744.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person109_bacteria_528.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person141_bacteria_676.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1647_virus_2848.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person171_bacteria_826.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person133_bacteria_635.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1653_virus_2858.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1661_virus_2873.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person91_bacteria_445.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1_virus_12.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person133_bacteria_637.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person11_virus_38.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person123_bacteria_587.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person70_virus_130.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/
jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person15_virus_46.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person142_bacteria_684.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person124_bacteria_589.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person134_bacteria_644.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person152_bacteria_722.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person141_bacteria_670.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person100_bacteria_475.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person143_bacteria_688.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person111_bacteria_537.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1671_virus_2887.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person94_bacteria_456.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person96_bacteria_465.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person139_bacteria_663.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person142_bacteria_683.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person119_bacteria_566.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person172_bacteria_827.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1669_virus_2884.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person78_bacteria_387.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person155_bacteria_729.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person114_bacteria_545.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person71_virus_132.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person144_bacteria_690.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person82_bacteria_405.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person14_virus_44.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person97_bacteria_468.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1661_virus_2872.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person152_bacteria_720.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person50_virus_102.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person142_bacteria_682.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person41_virus_88.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person143_bacteria_689.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person81_bacteria_397.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person125_bacteria_595.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person55_virus_110.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person138_bacteria_659.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person139_bacteria_665.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person100_bacteria_477.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person152_bacteria_721.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1634_virus_2830.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person101_bacteria_483.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1660_virus_2869.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person109_bacteria_523.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person39_virus_85.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person136_bacteria_649.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person20_virus_51.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person120_bacteria_573.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person128_bacteria_608.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1642_virus_2842.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person88_bacteria_439.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person114_bacteria_546.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person113_bacteria_541.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person38_virus_83.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person75_virus_136.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person100_bacteria_482.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person1622_virus_2810.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person108_bacteria_511.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person136_bacteria_654.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person173_bacteria_831.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/test/PNEUMONIA/person111_bacteria_533.jpeg
# (28, 28, 1) PNEUMONIA
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/.DS_Store
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0856-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/IM-0316-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0860-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/IM-0580-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/IM-0547-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/IM-0471-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001-0002.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0859-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/IM-0497-0001-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/IM-0522-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/IM-0466-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0575-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0627-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0723-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/IM-0588-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/IM-0640-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/IM-0534-0001.jpeg
# (28, 28, 1) NORMAL
# /kaggle/input/chest-xray-pneumonia/chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0942-0001.jpeg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1be784df5a74> in <module>
#      25         img = cv2.imread(filename,cv2.IMREAD_GRAYSCALE)
#      26         if img is not None:
# ---> 27                 img = skimage.transform.resize(img, (28,28, 1))
#      28                 img = np.asarray(img)
#      29                 label=filename.split('/')[-2]
#
# /opt/conda/lib/python3.6/site-packages/skimage/transform/_warps.py in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     147
#     148         image = ndi.gaussian_filter(image, anti_aliasing_sigma,
# --> 149                                     cval=cval, mode=ndi_mode)
#     150
#     151     # 2-dimensional interpolation
#
# /opt/conda/lib/python3.6/site-packages/scipy/ndimage/filters.py in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     287         for axis, sigma, order, mode in axes:
#     288             gaussian_filter1d(input, sigma, axis, order, output,
# --> 289                               mode, cval, truncate)
#     290             input = output
#     291     else:
#
# /opt/conda/lib/python3.6/site-packages/scipy/ndimage/filters.py in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     205     # Since we are calling correlate, not convolve, revert the kernel
#     206     weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 207     return correlate1d(input, weights, axis, output, mode, cval, 0)
#     208
#     209
#
# /opt/conda/lib/python3.6/site-packages/scipy/ndimage/filters.py in correlate1d(input, weights, axis, output, mode, cval, origin)
#      93     mode = _ni_support._extend_mode_to_code(mode)
#      94     _nd_image.correlate1d(input, weights, axis, output, mode, cval,
# ---> 95                           origin)
#      96     return output
#      97
#
# KeyboardInterrupt:

# %%
X = np.asarray(X)
y = np.asarray(y)

# %%
X.shape, y.shape
# Out:
# ((641, 28, 28, 1), (641,))

# %%
# now for rf, flatten each image 
X_rf=[]
for i in range(X.shape[0]):
    a=X[i].flatten()
    X_rf.append(a)
X_rf=np.asarray(X_rf)

# %%
X_rf.shape, y.shape
# Out:
# ((641, 784), (641,))
