# %%
import requests
origin = '1 Rocket Road, Hawthorne, CA'
destination = '1 Rocket Road, McGregor, TX'
apiKey='AIzaSyB6YZmbNdDLv7tQdYyQFvYUd_X8o2jWdz4' 


url = ('https://maps.googleapis.com/maps/api/distancematrix/json?units=imperial&origins={}&destinations={}&key={}'
           .format(origin.replace(' ','+'),
                   destination.replace(' ','+'),
                   apiKey
                  )
          )

response = requests.get(url)
resp_json = response.json()

# %%
resp_json
# Out:
# {u'destination_addresses': [u'1 Rocket Rd, McGregor, TX 76657, USA'],
#  u'origin_addresses': [u'1 Rocket Rd, Hawthorne, CA 90250, USA'],
#  u'rows': [{u'elements': [{u'distance': {u'text': u'1,414 mi',
#       u'value': 2276067},
#      u'duration': {u'text': u'20 hours 38 mins', u'value': 74267},
#      u'status': u'OK'}]}],
#  u'status': u'OK'}

# %%
url= 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Restaurants%20San%20Francisco&inputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key={}'.format(apiKey)

# %%
response = requests.get(url)
resp_json = response.json()

# %%
resp_json
# Out:
# {u'candidates': [{u'formatted_address': u'295 Eddy St, San Francisco, CA 94102, United States',
#    u'geometry': {u'location': {u'lat': 37.7838287, u'lng': -122.4123537},
#     u'viewport': {u'northeast': {u'lat': 37.78524972989273,
#       u'lng': -122.4110191701073},
#      u'southwest': {u'lat': 37.78255007010728, u'lng': -122.4137188298928}}},
#    u'name': u'Z Zoul Cafe',
#    u'opening_hours': {u'open_now': True},
#    u'photos': [{u'height': 3024,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/107373923787849028827/photos">Phillip Pierce</a>'],
#      u'photo_reference': u'CmRaAAAAs_ekmNc5Ky1z_WFH_YAx6axYI9fT0Bv21VMvreEo40DMTe0GqmQFQpIDz_UYjtBUsSzBQDU-JdN5ws7Nl-RBmfDNWqJFanBtxFfXgkjo-54-W7N9V1ikpOiU4pA9xrjXEhCvZmLjf6NkJcDyRJ_9qdJMGhQ_cz_AnfGR3TnVsDYzl6mDC3Nt0A',
#      u'width': 4032}],
#    u'rating': 4.7}],
#  u'status': u'OK'}

# %%
#specify the longtitude and latitude 

url='https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.8976763%2C-77.0365298&radius=1000&keyword=restaurant&key={}'.format(apiKey)
response = requests.get(url)
resp_json= response.json()

# %%
resp_json
# Out:
# {u'html_attributions': [],
#  u'next_page_token': u'CrQCIQEAAAj4745PlLA1U7a-sbUcr5CgHyg5EOk8OJVGjzsFjwLoX5wkYSnN09hq-xI-4DtpYkQ6aHERazhaPQtqh0IlYgrJBYC0X6ujKy1wTQURsVN3Xrr2HVJF-iR6Co_3HZf0srxvATwM6zsxH0SXIq_1ByRhffG6MBdaXGKGUNviah-Vo8x8iECsMz6uZGP3CKn_oQUJj7ib-ykqGq6KOSGhTII7NT8u9ZMScSaQVtdQrzbp64EKd3qrixh9ncSNlZWqqwhw8lUEQKAC2mn0iR3UOeWHU5OSC_XLDViCcxlmv_SqTxs2abCCj9yUHOecFdCqdopeqBSJFFt5DZBlk7ZMopUM4aQOxVNzZaMdkKncsJh4aQddzc0hzOrPJOn3DRRX5R_YndVJA38XquROwS0ssSMSEKByGwb7vmKvYtk-sxJ7-wQaFIEMGOHbELF3guedNNOuwxYAFjcw',
#  u'results': [{u'geometry': {u'location': {u'lat': 38.897954,
#      u'lng': -77.0333395},
#     u'viewport': {u'northeast': {u'lat': 38.89934997989272,
#       u'lng': -77.03216057010728},
#      u'southwest': {u'lat': 38.89665032010728, u'lng': -77.03486022989273}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'7fe59b69ed22ba94e6101f5a7e838b4cf4588ef9',
#    u'name': u'Old Ebbitt Grill',
#    u'opening_hours': {u'open_now': True},
#    u'photos': [{u'height': 750,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/111419326936123221540/photos">Keith Cross</a>'],
#      u'photo_reference': u'CmRaAAAAl6NtTGIEPLX-ypMa4U47a50bD9lb8nWFqM3AttnTKuiZX8Pn_RScqVOQnt1nneOWXF9eOlD6VShZxqpOS5DSulsWDXyNmcEqGh1bNcc-pdFdhXcLNRsUPNcbvqceu6ETEhAVnD4oMjg0HwyuMIOToYvfGhR0_7422bYTo3LuCm7zYqV5mSF7gA',
#      u'width': 1000}],
#    u'place_id': u'ChIJgRwXf723t4kRdfqt36VafUU',
#    u'plus_code': {u'compound_code': u'VXX8+5M Washington, District of Columbia',
#     u'global_code': u'87C4VXX8+5M'},
#    u'price_level': 2,
#    u'rating': 4.6,
#    u'reference': u'ChIJgRwXf723t4kRdfqt36VafUU',
#    u'scope': u'GOOGLE',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 9352,
#    u'vicinity': u'675 15th St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9066664, u'lng': -77.04304359999999},
#     u'viewport': {u'northeast': {u'lat': 38.90801762989273,
#       u'lng': -77.04189442010728},
#      u'southwest': {u'lat': 38.90531797010728, u'lng': -77.04459407989272}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'31ca9440a9a588c3e6b7d2fc2d0d2e631c0484af',
#    u'name': u'The Palm Washington DC',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 3006,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/107016018053445290905/photos">Jim Stevens</a>'],
#      u'photo_reference': u'CmRaAAAAbFGmjAi-ntq7lvd8f7fCJvIZAzLgVuk5eymF3g51OI2x5UOTVYDIpzo6otEQYdOarYfM47OKcQx4bfg2BQWXauJDJRjfbn1so9XC9qBgHwFOLw_dPjbvL-WKGQ7dxM4hEhC-JLB1e6C1GeuR7_pTwjtQGhQfhYyebSsxRiqGrLTm0EXbjcPE-g',
#      u'width': 5344}],
#    u'place_id': u'ChIJO9-Yc7i3t4kRkJ_rj1jWyN4',
#    u'plus_code': {u'compound_code': u'WX44+MQ Washington, District of Columbia',
#     u'global_code': u'87C4WX44+MQ'},
#    u'price_level': 4,
#    u'rating': 4.4,
#    u'reference': u'ChIJO9-Yc7i3t4kRkJ_rj1jWyN4',
#    u'scope': u'GOOGLE',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 464,
#    u'vicinity': u'1225 19th St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9009528, u'lng': -77.0386407},
#     u'viewport': {u'northeast': {u'lat': 38.90233992989272,
#       u'lng': -77.03718547010729},
#      u'southwest': {u'lat': 38.89964027010728, u'lng': -77.03988512989272}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'95b2b0a2bd0fdea7687bb9c8340216abd130998b',
#    u'name': u'Equinox Restaurant',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 3024,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/101445184449021885954/photos">Steve Smith</a>'],
#      u'photo_reference': u'CmRaAAAAZp0ibJfzzCfI0toMly_KU0FqbUMXUUliBMT0CYDzFWWgcBMdkXPpgnp0Gry0QPojWI7nZQMBy77WW60Rwqp2BszHLssv0gNS6mhhuOWZGh-fqNtnupQz4uuz2U6jvDMVEhC06XMFVVzlMJtn1NRxzA-jGhSbK3xs9Xh9RI3bHZ_-N3wMHOUr4w',
#      u'width': 4032}],
#    u'place_id': u'ChIJt6jHBLy3t4kRI2hxAOiO8fw',
#    u'plus_code': {u'compound_code': u'WX26+9G Washington, District of Columbia',
#     u'global_code': u'87C4WX26+9G'},
#    u'price_level': 3,
#    u'rating': 4.5,
#    u'reference': u'ChIJt6jHBLy3t4kRI2hxAOiO8fw',
#    u'scope': u'GOOGLE',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment'],
#    u'user_ratings_total': 391,
#    u'vicinity': u'818 Connecticut Ave NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.905435, u'lng': -77.02688619999999},
#     u'viewport': {u'northeast': {u'lat': 38.90678502989272,
#       u'lng': -77.02561417010726},
#      u'southwest': {u'lat': 38.90408537010728, u'lng': -77.02831382989271}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'd5d45f77ebd658481c66554c94b3055466c2094a',
#    u'name': u'El Rinconcito Cafe',
#    u'opening_hours': {u'open_now': True},
#    u'photos': [{u'height': 4032,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/106517359481359344927/photos">Wesley Rogerson</a>'],
#      u'photo_reference': u'CmRaAAAA0sLZa6MFzzS_lpDro_HdBYYeS8MdYNX71k9RNKz2dQOWARRGTmuAA_cjlKXvRiMiTdPTxZqOOljE0AXaP_Rwakwni5EqOGBcnJwj9IAl_cixQjsp4q5TtmM6yNWC7B87EhBLE_q6TEOdwaIbd8CAkLJfGhTvVWHttFJdvKcjAmdoBISL2o3mww',
#      u'width': 3024}],
#    u'place_id': u'ChIJ-e5isuy3t4kR0yUQB3gAOkI',
#    u'plus_code': {u'compound_code': u'WX4F+56 Washington, District of Columbia',
#     u'global_code': u'87C4WX4F+56'},
#    u'price_level': 1,
#    u'rating': 4.5,
#    u'reference': u'ChIJ-e5isuy3t4kR0yUQB3gAOkI',
#    u'scope': u'GOOGLE',
#    u'types': [u'cafe',
#     u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 722,
#    u'vicinity': u'1129 11th St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.8977735, u'lng': -77.0298098},
#     u'viewport': {u'northeast': {u'lat': 38.89915487989271,
#       u'lng': -77.02840962010727},
#      u'southwest': {u'lat': 38.89645522010727, u'lng': -77.03110927989272}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'f176f2d33bab3f6d652b7ba1277b27bd4318ab68',
#    u'name': u"Mastro's Steakhouse",
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 2340,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/106030642514027235282/photos">A Google User</a>'],
#      u'photo_reference': u'CmRaAAAAVlsIUA-UtzYLTX63-JYYvjDfjLXCe4zYzoiOZsl_n3_RiGzOTBZFqoMPa4M6SIMjtnH2B-9tSmzSS4tcDnYWz-bvyhPqzjE3dcxVVeSspOkQ1nfD33TNFwG6AOUFztJeEhDNJEtggfC5rawwivgsLXQ4GhStewVbmAtAIuu65GjBk-32203VHw',
#      u'width': 4160}],
#    u'place_id': u'ChIJH8SJApe3t4kR62qR9vTHuwE',
#    u'plus_code': {u'compound_code': u'VXXC+43 Washington, District of Columbia',
#     u'global_code': u'87C4VXXC+43'},
#    u'price_level': 4,
#    u'rating': 4.5,
#    u'reference': u'ChIJH8SJApe3t4kR62qR9vTHuwE',
#    u'scope': u'GOOGLE',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment'],
#    u'user_ratings_total': 821,
#    u'vicinity': u'600 13th St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9017993, u'lng': -77.0334319},
#     u'viewport': {u'northeast': {u'lat': 38.90314842989272,
#       u'lng': -77.03218597010728},
#      u'southwest': {u'lat': 38.90044877010728, u'lng': -77.03488562989271}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'8fa168f5728e1a98d07533d97f5a1c5fa09743fa',
#    u'name': u'Siroc Restaurant',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 2268,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/114256495941293334079/photos">Caitlin Sweeney</a>'],
#      u'photo_reference': u'CmRaAAAAk7xS878Y2THt4uQBSjg2wUTAKX48xSj4NmRWY_5ySOmVkWWDZ2AKeG2gg2lW2XXDbuuaNnjqZ0ccZOcSxknVA93QuCXeuRbqblC-cfgBSpXT0GZbQU_caGlhQ61nTEn_EhD4ojhW7ota_Nqai7JCnnRBGhReuqZKmSbiaPPckFvPYkd8s65hwA',
#      u'width': 4032}],
#    u'place_id': u'ChIJx1-IHr63t4kRcquq9ByDA8I',
#    u'plus_code': {u'compound_code': u'WX28+PJ Washington, District of Columbia',
#     u'global_code': u'87C4WX28+PJ'},
#    u'price_level': 2,
#    u'rating': 4.4,
#    u'reference': u'ChIJx1-IHr63t4kRcquq9ByDA8I',
#    u'scope': u'GOOGLE',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment'],
#    u'user_ratings_total': 310,
#    u'vicinity': u'915 15th St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9050421, u'lng': -77.0480125},
#     u'viewport': {u'northeast': {u'lat': 38.90632827989272,
#       u'lng': -77.04659077010727},
#      u'southwest': {u'lat': 38.90362862010728, u'lng': -77.04929042989271}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'a1cf716305cfc6feb4fe5c9d9ea3f9b04cb7f367',
#    u'name': u'Rasika West End',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 1360,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/101802336627278695204/photos">Amanda Spurlock</a>'],
#      u'photo_reference': u'CmRaAAAAnlJQBnx-mSzIQ_znOjwfmg51FwSRt5jjMkNBDeKtl6dntY8BUDUT9XJEeAs_V1lJX1K7QvOB5309HSkALwl91D-YF-3jFfdcc722jZ_nuZKouiOY6t6y7F2kE4qaHXxIEhCrB97XFL0rn4dGu2Q2mCJCGhSd_5pQOK8r0JOD4L5SStocv1ytgg',
#      u'width': 2048}],
#    u'place_id': u'ChIJMUs6-ra3t4kRueqJ32bEmDU',
#    u'plus_code': {u'compound_code': u'WX42+2Q Washington, District of Columbia',
#     u'global_code': u'87C4WX42+2Q'},
#    u'price_level': 3,
#    u'rating': 4.4,
#    u'reference': u'ChIJMUs6-ra3t4kRueqJ32bEmDU',
#    u'scope': u'GOOGLE',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 943,
#    u'vicinity': u'1190 New Hampshire Ave NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9018744, u'lng': -77.03476409999999},
#     u'viewport': {u'northeast': {u'lat': 38.90322507989272,
#       u'lng': -77.03332307010726},
#      u'southwest': {u'lat': 38.90052542010728, u'lng': -77.03602272989271}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'c8295afa228819f7eec819d19c7007dfa3942574',
#    u'name': u"Georgia Brown's",
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 2988,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/102714109837520554923/photos">Alina Diaz</a>'],
#      u'photo_reference': u'CmRaAAAAkqY3ErA5URxKj_x1jIPk_714b6Ib77YRJcd_jQTTouNmyOdBY_r0rnFDMW7w0-LE6MrhK4nxC5ab9yak9XPpigNWPC4wwk_uyGd-hUtxCPLS2ykUyuzcJ-15Gw_JjJ7AEhBXvjKGCGS39EtmgPT9YfIeGhSMiKbJa9uUFw8boaGQknB48Ql-QA',
#      u'width': 5312}],
#    u'place_id': u'ChIJweENE763t4kRpfaSKMj6tOs',
#    u'plus_code': {u'compound_code': u'WX28+P3 Washington, District of Columbia',
#     u'global_code': u'87C4WX28+P3'},
#    u'price_level': 2,
#    u'rating': 4.3,
#    u'reference': u'ChIJweENE763t4kRpfaSKMj6tOs',
#    u'scope': u'GOOGLE',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 1759,
#    u'vicinity': u'950 15th St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9065813, u'lng': -77.0273091},
#     u'viewport': {u'northeast': {u'lat': 38.90793067989272,
#       u'lng': -77.02582377010728},
#      u'southwest': {u'lat': 38.90523102010728, u'lng': -77.02852342989272}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'7f6ce8a4bbee37725c7bcd9b8172cb98f61686d4',
#    u'name': u'Tortino Restaurant',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 4032,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/117920589919707441121/photos">Kyle D</a>'],
#      u'photo_reference': u'CmRaAAAAxqp7pI_XosL-RrhLMFt01ZZ_zLcF2cGN5d7ku9W8oiQBrTaYd6cpU0XqkH-_-WZMnZcI0Iu6lvrnrxMaBNeme4Ai9_V7Q6Zg_GDpw_LBEoWT_GO9CI24tH9i-ESEzQFZEhDJI2KQdgYlcs_-Imz298nHGhQOTmRTi5AtjWA-icEwOYflPzh4-w',
#      u'width': 3024}],
#    u'place_id': u'ChIJScgTouy3t4kRxZH3rEzhwSE',
#    u'plus_code': {u'compound_code': u'WX4F+J3 Washington, District of Columbia',
#     u'global_code': u'87C4WX4F+J3'},
#    u'price_level': 2,
#    u'rating': 4.6,
#    u'reference': u'ChIJScgTouy3t4kRxZH3rEzhwSE',
#    u'scope': u'GOOGLE',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment'],
#    u'user_ratings_total': 388,
#    u'vicinity': u'1228 11th St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.90161440000001,
#      u'lng': -77.02687259999999},
#     u'viewport': {u'northeast': {u'lat': 38.90296352989273,
#       u'lng': -77.02560672010728},
#      u'southwest': {u'lat': 38.90026387010728, u'lng': -77.02830637989271}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'b2b2e15c3dddbef18e072d3ada0abbdbc8043b64',
#    u'name': u'Sfoglina Downtown',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 3427,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/118418188481799920452/photos">Sfoglina Downtown</a>'],
#      u'photo_reference': u'CmRaAAAAyrcB2eDVNmKJmc-ZOZzv3KlkUdZCrL_b_hSHdJjcpqNE4Pr4VaAEgQ-JLbabKaujphckMj71AG--oPm1geAu5C_M2c4PPrXhv-zUUNC2IBs821PvlHjvSbsdKoMoAcicEhAEj4H_KoOrMvZknDtZamsVGhSlEBiHcISFQpTXrT8Q54yGIWkA8w',
#      u'width': 5239}],
#    u'place_id': u'ChIJGVmxk5O3t4kRHETQmsUTRYs',
#    u'plus_code': {u'compound_code': u'WX2F+J7 Washington, District of Columbia',
#     u'global_code': u'87C4WX2F+J7'},
#    u'price_level': 3,
#    u'rating': 4.5,
#    u'reference': u'ChIJGVmxk5O3t4kRHETQmsUTRYs',
#    u'scope': u'GOOGLE',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 472,
#    u'vicinity': u'1099 New York Ave NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9007039, u'lng': -77.0268734},
#     u'viewport': {u'northeast': {u'lat': 38.90199157989272,
#       u'lng': -77.02560067010727},
#      u'southwest': {u'lat': 38.89929192010728, u'lng': -77.02830032989272}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'ac65e75da683afd75c92acd71e4e83eb94563225',
#    u'name': u'Momofuku CCDC',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 3024,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/118313507425888687343/photos">Adrian Roo</a>'],
#      u'photo_reference': u'CmRaAAAAlr9uH8RX55EA1DGGn6IaHEn2NVRuu2kE5KQXcH2W2pUnXn2uc0m2Yi6Gu-B3cAiM-tYBRHgHLTaJvLLOX7BGcyw6lGYS2h0FBZFMizvx0UkwMFrDh027VSsL2XKHYEpLEhB7K9VXKoQJKtklJI15WffVGhTi6Bb3Z93Oo7FslQilBzxvqt_r_A',
#      u'width': 4032}],
#    u'place_id': u'ChIJ-6zk5ZO3t4kRwi3BXpaCRjE',
#    u'plus_code': {u'compound_code': u'WX2F+77 Washington, District of Columbia',
#     u'global_code': u'87C4WX2F+77'},
#    u'price_level': 2,
#    u'rating': 4.2,
#    u'reference': u'ChIJ-6zk5ZO3t4kRwi3BXpaCRjE',
#    u'scope': u'GOOGLE',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment'],
#    u'user_ratings_total': 1149,
#    u'vicinity': u'1090 I St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9021684, u'lng': -77.0368272},
#     u'viewport': {u'northeast': {u'lat': 38.90358607989273,
#       u'lng': -77.03534037010726},
#      u'southwest': {u'lat': 38.90088642010728, u'lng': -77.03804002989271}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'1cb4f800baec353d7e2892f24527ae7ca7aa21ed',
#    u'name': u'P.J. Clarke\u2019s DC',
#    u'opening_hours': {u'open_now': True},
#    u'photos': [{u'height': 4608,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/109725302102272961183/photos">Sumit Mukerjee</a>'],
#      u'photo_reference': u'CmRaAAAAx1zsia9GB7UriBmVStitXnsMvZjbYsE6lqmCBHZsjxvffT2aJZN7CF-AmwBG-bujFFXRZW2JDp8J01N0Vch9s_7Xr7Ovhf9A90eeXdMgNnZYi-G3pqYfXUE_8wxEsMW4EhAFf-0byhrHf_Js6sCMdfihGhT_yqm8lmT3ffznIg-2C-pRNGJkCw',
#      u'width': 3456}],
#    u'place_id': u'ChIJSyXWjb63t4kR9yLeWUKcYjU',
#    u'plus_code': {u'compound_code': u'WX27+V7 Washington, District of Columbia',
#     u'global_code': u'87C4WX27+V7'},
#    u'price_level': 2,
#    u'rating': 4.2,
#    u'reference': u'ChIJSyXWjb63t4kR9yLeWUKcYjU',
#    u'scope': u'GOOGLE',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 753,
#    u'vicinity': u'1600 K St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9064602, u'lng': -77.0249214},
#     u'viewport': {u'northeast': {u'lat': 38.90819897989272,
#       u'lng': -77.02354512010727},
#      u'southwest': {u'lat': 38.90549932010727, u'lng': -77.02624477989272}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'813a211a36458af25d2940b964a6dcb59a9c5b9e',
#    u'name': u'Tiger Fork',
#    u'opening_hours': {u'open_now': True},
#    u'photos': [{u'height': 3024,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/106694180620463861899/photos">Chris Kremser</a>'],
#      u'photo_reference': u'CmRaAAAAkd2xTB9k284vAXbhYOFCRZLNy2AOd2-mfd7FVOfKNLNxQE1HQldgDCYBzV28tg6Ms5kqFAh1RbN5l_Sp4gOdK8235Jl3JFqQ-0JXP-LgjHaux-ZJ9R3w5j3epu5Xy7SMEhCPjYiPxLfuZZYS3RnDQ228GhR4uaqbSwTVwWVwrOcUsfo-mDPrDg',
#      u'width': 4032}],
#    u'place_id': u'ChIJTRIX_ey3t4kRGkTeAWsk_9w',
#    u'plus_code': {u'compound_code': u'WX4G+H2 Washington, District of Columbia',
#     u'global_code': u'87C4WX4G+H2'},
#    u'price_level': 2,
#    u'rating': 4.4,
#    u'reference': u'ChIJTRIX_ey3t4kRGkTeAWsk_9w',
#    u'scope': u'GOOGLE',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment'],
#    u'user_ratings_total': 501,
#    u'vicinity': u'922 Blagden Alley, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.905994, u'lng': -77.036973},
#     u'viewport': {u'northeast': {u'lat': 38.90734542989273,
#       u'lng': -77.03567782010728},
#      u'southwest': {u'lat': 38.90464577010729, u'lng': -77.03837747989273}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'a87c0dfe0a4c56e490e9eea4b55854becb2efaa6',
#    u'name': u'Plume',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 4032,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/115972922830366655018/photos">Adonica Black</a>'],
#      u'photo_reference': u'CmRaAAAAa09PcD4Hg454MbLpw9-Y7GlIgFYgnf-BGlTnXjLRRi3aPjPReJkPMeBi1BpqZQ4tOXqkZjgkEfRcnj9kmJ7fM4O3Jo78vbGxem6cCU8s8JNA42dKQv-lEY1-nvvVfGXCEhD7OPPcZ49VRHi0TtMNFf17GhRJURrKb5kyW6QEtXi1fj8I491_iw',
#      u'width': 3024}],
#    u'place_id': u'ChIJOYdIe7-3t4kRgv2U126-AL8',
#    u'plus_code': {u'compound_code': u'WX47+96 Washington, District of Columbia',
#     u'global_code': u'87C4WX47+96'},
#    u'price_level': 4,
#    u'rating': 4.5,
#    u'reference': u'ChIJOYdIe7-3t4kRgv2U126-AL8',
#    u'scope': u'GOOGLE',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 144,
#    u'vicinity': u'1200 16th St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.8976398, u'lng': -77.03248529999999},
#     u'viewport': {u'northeast': {u'lat': 38.89884527989273,
#       u'lng': -77.03113257010726},
#      u'southwest': {u'lat': 38.89614562010728, u'lng': -77.03383222989271}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'214817758526a2e5467a9b0247a0aff64500ae7c',
#    u'name': u'The Hamilton',
#    u'opening_hours': {u'open_now': True},
#    u'photos': [{u'height': 800,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/103036502084943676218/photos">The Hamilton</a>'],
#      u'photo_reference': u'CmRaAAAA79JgbMEuSWwSl_AB1hSHOUIaEzn7bnW3PDZokFYugd6iGJ4RBh_8JkGZhW4fII_KQbgYAg9ppq85qeByFo8gRIw-RGjY0SIjwLzv80pobJDV6n7qrNjzWflbkUb-CtJqEhD7WwKG7TM-6XqF85nSsNYWGhTSsN74GJ3XQa2Rw_rkUIVk0duF-Q',
#      u'width': 1246}],
#    u'place_id': u'ChIJ0zjVx5e3t4kRPiQqmswuh9c',
#    u'plus_code': {u'compound_code': u'VXX9+32 Washington, District of Columbia',
#     u'global_code': u'87C4VXX9+32'},
#    u'price_level': 2,
#    u'rating': 4.5,
#    u'reference': u'ChIJ0zjVx5e3t4kRPiQqmswuh9c',
#    u'scope': u'GOOGLE',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 4602,
#    u'vicinity': u'600 14th St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9057285, u'lng': -77.04772},
#     u'viewport': {u'northeast': {u'lat': 38.90697337989272,
#       u'lng': -77.04616187010727},
#      u'southwest': {u'lat': 38.90427372010728, u'lng': -77.04886152989272}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'5dd041a4806d454a912b1bd77af93da9250dc649',
#    u'name': u'Grillfish',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 3264,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/103515590700012214721/photos">Michael Garman</a>'],
#      u'photo_reference': u'CmRaAAAAfSZ5d8uHeb2AvUUfqWiW07IlttUwAgrK1xj2hJWKCAKHcdnleneDh9hTjAZKeXOgO9M87__a2LC4PVY_8O3_QHngyPyn1teMioWmjH1ToWxeJmoaUGRX4Iea34zi7D5lEhAODbYvHSgLOME7iQGVptqsGhS1ixdW1ZfuXm44-560_MCBhWdh0w',
#      u'width': 2448}],
#    u'place_id': u'ChIJgyFWsre3t4kRfe4CuUyQ7Lo',
#    u'plus_code': {u'compound_code': u'WX42+7W Washington, District of Columbia',
#     u'global_code': u'87C4WX42+7W'},
#    u'price_level': 2,
#    u'rating': 4.3,
#    u'reference': u'ChIJgyFWsre3t4kRfe4CuUyQ7Lo',
#    u'scope': u'GOOGLE',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 612,
#    u'vicinity': u'1200 New Hampshire Ave NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9002671, u'lng': -77.02553259999999},
#     u'viewport': {u'northeast': {u'lat': 38.90165522989273,
#       u'lng': -77.0244112701073},
#      u'southwest': {u'lat': 38.89895557010728, u'lng': -77.02711092989273}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'76fb97e04c9ab31ba3677fcb990b34deb542bb42',
#    u'name': u'Centrolina',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 5312,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/103947319407579105933/photos">Lee Gerson</a>'],
#      u'photo_reference': u'CmRaAAAA020U3TtbLt59gO7I96ZX2f9fwV3WJESuTuWu7Ql9BP4F7FlFYI5GuT47oT1Ygl2Ra8kH3PGuDCicYUN3X3C19mgneGLRO5SgxuWKBiJPuV8yRMlWHtfDtCXhA-gdkxWzEhApJ-sMCV9vplOnEh1i-NaeGhTE2xfwJXLsHAppImxJzHgF3RATKQ',
#      u'width': 2988}],
#    u'place_id': u'ChIJma782pO3t4kR-hKXI7SAq3U',
#    u'plus_code': {u'compound_code': u'WX2F+4Q Washington, District of Columbia',
#     u'global_code': u'87C4WX2F+4Q'},
#    u'price_level': 3,
#    u'rating': 4.4,
#    u'reference': u'ChIJma782pO3t4kR-hKXI7SAq3U',
#    u'scope': u'GOOGLE',
#    u'types': [u'grocery_or_supermarket',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'store',
#     u'establishment'],
#    u'user_ratings_total': 371,
#    u'vicinity': u'974 Palmer Alley NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.8970398, u'lng': -77.0276761},
#     u'viewport': {u'northeast': {u'lat': 38.89854597989272,
#       u'lng': -77.02630712010728},
#      u'southwest': {u'lat': 38.89584632010727, u'lng': -77.02900677989273}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'cdf1de22f8360946b64f542b0364f325a2dd1082',
#    u'name': u'Tosca',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 3492,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/107983370411696368436/photos">Melinda Russek</a>'],
#      u'photo_reference': u'CmRaAAAASH7sPLtA1oZf_xTy3PZoVbC4kQJYrM-fauxB7gEznwt_Wq-NmlnfbdFZK4QT5Za-4eaoDViy51urCzyekJ1sIYnWz1c4RMD96PCQcCmlppmOaZFM1DI2ajEl8mkX1rLDEhAl_BnCR0GM-QZ85m2MgEP-GhTl1jW3yzMMrZptnD8LcikZQdie1A',
#      u'width': 3492}],
#    u'place_id': u'ChIJdRoU1JC3t4kRaRCnXV0YIgw',
#    u'plus_code': {u'compound_code': u'VXWC+RW Washington, District of Columbia',
#     u'global_code': u'87C4VXWC+RW'},
#    u'price_level': 3,
#    u'rating': 4.4,
#    u'reference': u'ChIJdRoU1JC3t4kRaRCnXV0YIgw',
#    u'scope': u'GOOGLE',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment'],
#    u'user_ratings_total': 258,
#    u'vicinity': u'1112 F St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.906612, u'lng': -77.02681609999999},
#     u'viewport': {u'northeast': {u'lat': 38.90796217989272,
#       u'lng': -77.02557722010727},
#      u'southwest': {u'lat': 38.90526252010727, u'lng': -77.02827687989272}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'e28dacb56c225d614baecf7236d56361678363ae',
#    u'name': u'El Sol Restaurante & Tequileria',
#    u'opening_hours': {u'open_now': True},
#    u'photos': [{u'height': 1440,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/117625793807359725587/photos">Edith Jimenez</a>'],
#      u'photo_reference': u'CmRZAAAAT7r9WBuKxpiyK-bNDddN2HIRv_H6GwjrywcID9hTYnjPW3tc5VU8rWWEonQAP1fEZzGeqXeOl8MX4iiwzT3Gr9qRGckQtQJEvjVOmqbBSbrR2ZgAhiSi6Z1pNWnp1opCEhBJiEwTRpx0N_Lu7YfdYp5rGhS40-qIsGf6x7GCwQQSoE29S4jjwQ',
#      u'width': 2560}],
#    u'place_id': u'ChIJaV-wl-y3t4kR1W6OUZDXaB4',
#    u'plus_code': {u'compound_code': u'WX4F+J7 Washington, District of Columbia',
#     u'global_code': u'87C4WX4F+J7'},
#    u'price_level': 1,
#    u'rating': 4.4,
#    u'reference': u'ChIJaV-wl-y3t4kR1W6OUZDXaB4',
#    u'scope': u'GOOGLE',
#    u'types': [u'restaurant', u'food', u'point_of_interest', u'establishment'],
#    u'user_ratings_total': 776,
#    u'vicinity': u'1227 11th St NW, Washington'},
#   {u'geometry': {u'location': {u'lat': 38.9027631, u'lng': -77.0273334},
#     u'viewport': {u'northeast': {u'lat': 38.90411507989273,
#       u'lng': -77.02583282010728},
#      u'southwest': {u'lat': 38.90141542010728, u'lng': -77.02853247989273}}},
#    u'icon': u'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    u'id': u'13b4222df3360a6d43514c051d6fe20ef52ae618',
#    u'name': u'Brasserie Beck',
#    u'opening_hours': {u'open_now': False},
#    u'photos': [{u'height': 3024,
#      u'html_attributions': [u'<a href="https://maps.google.com/maps/contrib/100512636404916192782/photos">A Google User</a>'],
#      u'photo_reference': u'CmRaAAAAY-8IwjWU3HDQsUZzD-We6FLf56aOZcsQfWlD-icjwSVLFMi1xgaVpy4rFdqCJDWY2l_S8-n7t1gNkt5n8LvhbebEO1mqXa4P1bIhFwrne6STA7rSIJfQa4zyHeQ7zZHuEhCEeDl-abYdiTaZphgG0eJZGhS5MYS2CDYUcfg3vgS3QVHakqYUOw',
#      u'width': 4032}],
#    u'place_id': u'ChIJOfcdg5O3t4kRIMjWYOHtOek',
#    u'plus_code': {u'compound_code': u'WX3F+43 Washington, District of Columbia',
#     u'global_code': u'87C4WX3F+43'},
#    u'price_level': 3,
#    u'rating': 4.4,
#    u'reference': u'ChIJOfcdg5O3t4kRIMjWYOHtOek',
#    u'scope': u'GOOGLE',
#    u'types': [u'bar',
#     u'restaurant',
#     u'food',
#     u'point_of_interest',
#     u'establishment'],
#    u'user_ratings_total': 665,
#    u'vicinity': u'1101 K St NW, Washington'}],
#  u'status': u'OK'}

# %%
resp_json['results'][0]['name'], resp_json['results'][0]['vicinity'], resp_json['results'][0]['rating']
# Out:
# (u'Old Ebbitt Grill', u'675 15th St NW, Washington', 4.6)

# %%
names=[]
locations=[] 
ratings=[] 
for i in range(20): 
    names.append(resp_json['results'][i]['name'])
    locations.append(resp_json['results'][i]['vicinity'])
    ratings.append(resp_json['results'][i]['rating'])

# %%
import pandas as pd 
df=pd.DataFrame()
df['name']=names 
df['location']=locations 
df['rating']=ratings

# %%
df.head(2)
# Out:
#                      name                     location  rating
# 0        Old Ebbitt Grill   675 15th St NW, Washington     4.6
# 1  The Palm Washington DC  1225 19th St NW, Washington     4.4

# %%
df.to_csv('Restaurants_Washington.csv', index=False)
